# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('haberman.csv')
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
df.columns = ['patient_age', 'operation_year', 'positive_axillary_nodes', 'survival_status']
df
# Out:
#      patient_age  operation_year  positive_axillary_nodes  survival_status
# 0             30              62                        3                1
# 1             30              65                        0                1
# 2             31              59                        2                1
# 3             31              65                        4                1
# 4             33              58                       10                1
# ..           ...             ...                      ...              ...
# 300           75              62                        1                1
# 301           76              67                        0                1
# 302           77              65                        3                1
# 303           78              65                        1                0
# 304           83              58                        2                0
#
# [305 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_age              305 non-null    int64
#  1   operation_year           305 non-null    int64
#  2   positive_axillary_nodes  305 non-null    int64
#  3   survival_status          305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %% [markdown]
# The coulmn operation_year should be an integer as it denotes the last two digits of the year in which the operation was conducted.

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                          0
# patient_age              0
# operation_year           0
# positive_axillary_nodes  0
# survival_status          0

# %%
flag_age=0
for w in df['patient_age']:
    if w<=0:
        flag_age=flag_age+1
flag_age
# Out:
# 0

# %%
flag_Operation_year=0
for x in df['patient_age']:
    if x<=0:
        flag_Operation_year=flag_Operation_year+1
flag_Operation_year
# Out:
# 0

# %%
flag_survival_status=0
for y in df['survival_status']:
    if y<0:
        flag_survival_status=flag_survival_status+1
flag_survival_status
# Out:
# 0

# %%
flag_survival_status=0
for z in df['survival_status']:
    if z>1:
        flag_survival_status=flag_survival_status+1
flag_survival_status
# Out:
# 81

# %%
flag_survival_status=0
for z in df['survival_status']:
    if z==2:
        flag_survival_status=flag_survival_status+1
flag_survival_status
# Out:
# 81

# %%
df['survival_status'].replace(2,0,inplace=True)

# %%
df
# Out:
#      patient_age  operation_year  positive_axillary_nodes  survival_status
# 0             30              62                        3                1
# 1             30              65                        0                1
# 2             31              59                        2                1
# 3             31              65                        4                1
# 4             33              58                       10                1
# ..           ...             ...                      ...              ...
# 300           75              62                        1                1
# 301           76              67                        0                1
# 302           77              65                        3                1
# 303           78              65                        1                0
# 304           83              58                        2                0
#
# [305 rows x 4 columns]

# %%
df.describe()
# Out:
#        patient_age  operation_year  positive_axillary_nodes  survival_status
# count   305.000000      305.000000               305.000000       305.000000
# mean     52.531148       62.849180                 4.036066         0.734426
# std      10.744024        3.254078                 7.199370         0.442364
# min      30.000000       58.000000                 0.000000         0.000000
# 25%      44.000000       60.000000                 0.000000         0.000000
# 50%      52.000000       63.000000                 1.000000         1.000000
# 75%      61.000000       66.000000                 4.000000         1.000000
# max      83.000000       69.000000                52.000000         1.000000

# %%
df.corr()
# Out:
#                          patient_age  operation_year  positive_axillary_nodes  \
# patient_age                 1.000000        0.092623                -0.066548
# operation_year              0.092623        1.000000                -0.003277
# positive_axillary_nodes    -0.066548       -0.003277                 1.000000
# survival_status            -0.064351        0.004076                -0.286191
#
#                          survival_status
# patient_age                    -0.064351
# operation_year                  0.004076
# positive_axillary_nodes        -0.286191
# survival_status                 1.000000

# %%
sns.heatmap(df.corr(),cmap='magma',linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('haberman.csv')
df.columns = ['patient_age', 'operation_year', 'positive_axillary_nodes', 'survival_status']

# %% [markdown]
# Outliers:

# %%
sns.violinplot(df['patient_age'])
# Out:
# C:\Users\ARYAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='patient_age'>

# %%
sns.violinplot(df['operation_year'])
# Out:
# C:\Users\ARYAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='operation_year'>

# %%
sns.violinplot(df['positive_axillary_nodes'])
# Out:
# C:\Users\ARYAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='positive_axillary_nodes'>

# %% [markdown]
# The column positive_axillary_nodes may possibly have outliers, however for a better understanding we would need to have a reference of the datasource as well as the desired model to be built.
